# %% [markdown]
# # Their code

# %% [markdown]
# ## Importing Libraries
#
# > Add blockquote

# %%
# !pip install gplearn
# Out:
# Collecting gplearn
#   Downloading gplearn-0.4.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from gplearn) (1.5.2)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gplearn) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (3.5.0)
# Downloading gplearn-0.4.2-py3-none-any.whl (25 kB)
# Installing collected packages: gplearn
# Successfully installed gplearn-0.4.2

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import gplearn
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Downloading Financial Data

# %%
stocks = ['DIA', 'SPY', 'GLD', 'AAPL', 'XOM', 'GOOG', 'F', 'IWM']
#Any random number of stocks can be added or dropped(Make sure to also edit portfoliostd function accordingly)

stocks = yf.download(stocks, start = "2014-01-01", end = "2024-01-01")
#Start and End time can be configured
# Out:
# [*********************100%***********************]  8 of 8 completed

# %% [markdown]
# ## Creating Log Return Data Frame

# %%
#Creating a data frame with the log returns
stocks_lr = np.log(1+stocks["Adj Close"].pct_change())
stocks_lr.dropna()
# Out:
# Ticker                         AAPL       DIA         F       GLD      GOOG  \
# Date
# 2014-01-03 00:00:00+00:00 -0.022211  0.001705  0.004523  0.010873 -0.007322
# 2014-01-06 00:00:00+00:00  0.005438 -0.003046  0.004503  0.001759  0.011088
# 2014-01-07 00:00:00+00:00 -0.007177  0.006568 -0.012920 -0.005707  0.019095
# 2014-01-08 00:00:00+00:00  0.006313 -0.003765  0.010350 -0.005909  0.002079
# 2014-01-09 00:00:00+00:00 -0.012853 -0.000974  0.019121  0.002874 -0.009677
# ...                             ...       ...       ...       ...       ...
# 2023-12-22 00:00:00+00:00 -0.005563 -0.000214  0.000810  0.004425  0.006467
# 2023-12-26 00:00:00+00:00 -0.002845  0.004138  0.008065  0.007592  0.000700
# 2023-12-27 00:00:00+00:00  0.000518  0.003218 -0.004831  0.004528 -0.009709
# 2023-12-28 00:00:00+00:00  0.002224  0.001247 -0.004044 -0.005832 -0.001132
# 2023-12-29 00:00:00+00:00 -0.005439 -0.000425 -0.012230 -0.001568 -0.002480
#
# Ticker                          IWM       SPY       XOM
# Date
# 2014-01-03 00:00:00+00:00  0.005070 -0.000164 -0.002409
# 2014-01-06 00:00:00+00:00 -0.008142 -0.002902  0.001507
# 2014-01-07 00:00:00+00:00  0.008316  0.006123  0.014049
# 2014-01-08 00:00:00+00:00  0.001307  0.000218 -0.003271
# 2014-01-09 00:00:00+00:00  0.000261  0.000654 -0.009775
# ...                             ...       ...       ...
# 2023-12-22 00:00:00+00:00  0.009275  0.002008  0.001768
# 2023-12-26 00:00:00+00:00  0.012920  0.004214  0.002254
# 2023-12-27 00:00:00+00:00  0.003521  0.001806 -0.004710
# 2023-12-28 00:00:00+00:00 -0.003816  0.000378 -0.014566
# 2023-12-29 00:00:00+00:00 -0.016455 -0.002899 -0.002098
#
# [2515 rows x 8 columns]

# %% [markdown]
# ## Creating Function to Calculate Portfolio Return
#
# ## Portfolio Return is given by:
# ### (Asset 1 Weight x Expected Return) + (Asset 2 Weight x Expected Return)..

# %%
#Function to calculate portfolio return
def portfolioreturn(weights):
    return np.dot(stocks_lr.mean(),weights)*252

# %% [markdown]
# ## Function to Calculate Portfolio Standard Deviation (Risk)
# ## Portfolio Risk is given by(example for 3 asset portfolio):

# %%
def portfoliostd(weights):
    return (np.dot(np.dot(stocks_lr.cov(),weights),weights))**(1/2)*np.sqrt(252)

# %% [markdown]
# ## Function to Generate Random Weights

# %%
def weightscreator(stocks_lr):
    rand = np.random.random(len(stocks_lr.columns))
    rand /= rand.sum()
    return rand

# %% [markdown]
# ## Function to Find Returns and Standard Deviation for "i" Random Portfolio Weight Arrays

# %%
returns = []
stds = []
w = []

for i in range(1000): #Use the number of iterations you seem fit
    weights = weightscreator(stocks_lr)
    returns.append(portfolioreturn(weights))
    stds.append(portfoliostd(weights))
    w.append(weights)

# %% [markdown]
# ## Using MatPlotLib To Plot the Efficient Frontier
#
# ## Where Efficient Frontier is the graph between Portfolio Risk and Return

# %%
plt.scatter(stds,returns,c="red",s=0.2,alpha=0.75) #Customise size according to number of iterations being plotter
plt.scatter(stds[returns.index(max(returns))], max(returns),c = "green", s=3) #Customise size for this too
plt.text(stds[returns.index(max(returns))],max(returns),"Maximum Return", fontsize=7) #Customise font size for this too
plt.scatter(min(stds),returns[stds.index(min(stds))] ,c = "blue", s=3) #Customise size for this too
plt.text(min(stds),returns[stds.index(min(stds))],"Minimum Variance", fontsize=7) #Customise font size for this too
plt.title("Efficient Frontier", fontsize = 20)
plt.xlabel("Portfoliostd(Risk)", fontsize = 15)
plt.ylabel("Portfolioreturn(Return)", fontsize = 15)
plt.figure(figsize=(30,20))
plt.show()

# %% [markdown]
# ## Finding Max Returns and Associated Risk

# %%
print("Max return =", max(returns))
print("Corresponding Standard Deviation =", stds[returns.index(max(returns))])
# Out:
# Max return = 0.15100748497704083
# Corresponding Standard Deviation = 0.208463038417107

# %% [markdown]
# ## Creating a Function to Return Weights of Portfolios with Returns >= Max Returns According to Efficient Frontier

# %%
for i in range(10000): #Use the number of iterations you seem fit
    weights = weightscreator(stocks_lr)
    if (portfolioreturn(weights) >= max(returns)):
        weight_new = weights
        print("Your Efficient Portfolio is:",weight_new) #Returns portfolio weights for above condition being satisfied
        break
# Out:
# Your Efficient Portfolio is: [0.32955786 0.1393137  0.03292934 0.05769026 0.27669054 0.06643742
#  0.00626036 0.09112052]

# %%
print("Returns corresponding to weights found :",portfolioreturn(weight_new)) #Prints return of found weights
print("Risk associated with weights found :",portfoliostd(weight_new)) #Prints Risk of found weights
# Out:
# Returns corresponding to weights found : 0.15207547903300891
# Risk associated with weights found : 0.20180068517938338

# %%
def create_fronteir_df(iterations):
  returns = []
  stds = []
  w = []
  sharpes = []

  for i in range(1000): #Use the number of iterations you seem fit
    weights = weightscreator(stocks_lr)

    current_returns = portfolioreturn(weights)
    returns.append(current_returns)

    current_std = portfoliostd(weights)
    stds.append(portfoliostd(weights))

    w.append(weights)

    sharpes.append(current_returns/current_std)



  output = pd.DataFrame(
        {
            'Weights' : w,
            'Returns' : returns,
            'Std' : stds,
            'Sharpe Value': sharpes
        }
    )


  return output

# %%
df = create_fronteir_df(1000)

# %%
best_sharpe = df[df['Sharpe Value'] == df['Sharpe Value'].max()]

# %%
best_sharpe
# Out:
#                                                Weights   Returns       Std  \
# 608  [0.2684605299901382, 0.14082134922497114, 0.04...  0.130107  0.161721
#
#      Sharpe Value
# 608      0.804517

# %% [markdown]
# # Our code

# %% [markdown]
# ## Creating input data for modeling

# %%
def create_input_data(stocks_, start, end):
  stocks = yf.download(stocks_, start = start, end = end)

  stocks_lr = np.log(1+stocks["Adj Close"].pct_change())
  stocks_lr = stocks_lr.dropna()


  number_of_blocks = math.floor(len(stocks_lr) / 30)

  list_of_blocks = []
  prev_days = 0
  days = 30

  for block in range(number_of_blocks):
    stock_data = stocks_lr.iloc[prev_days:days, :]

    stock_data['date_range'] = str(min(stock_data.index)) + ' - ' + str(max(stock_data.index))

    data = pd.DataFrame(columns = ['stock', 'date_range', 'block', 'MA_10', 'MA_20', 'MA_30', 'returns', 'future_returns'])

    for i in range(8):
      stock = stock_data.columns[i]
      MA_10 = stock_data.iloc[-10:,i].mean()
      MA_20 = stock_data.iloc[-20:,i].mean()
      MA_30 = stock_data.iloc[:,i].mean()
      returns = stock_data.iloc[:,i].sum()
      date_range = stock_data['date_range'][0]
      future_returns = 0
      block_num = block
      row = [stock, date_range, block_num, MA_10, MA_20, MA_30, returns, future_returns]

      data.loc[len(data)] = row

    list_of_blocks.append(data)
    prev_days = prev_days + 30
    days = days + 30



  for block in range(number_of_blocks-1):
    for i in range(8):
        list_of_blocks[block].iloc[i,7] = list_of_blocks[block+1].iloc[i,6]


  list_of_blocks = list_of_blocks[:-1]

  combined = pd.concat(list_of_blocks, ignore_index=True)

  return combined

# %%
# %%capture
training = create_input_data(['DIA', 'SPY', 'GLD', 'AAPL', 'XOM', 'GOOG', 'F', 'IWM'], start = "2014-01-01", end = "2019-01-01")

# %%
# %%capture
testing = create_input_data(['DIA', 'SPY', 'GLD', 'AAPL', 'XOM', 'GOOG', 'F', 'IWM'], start = "2019-01-02", end = "2024-01-01")

# %%
training
# Out:
#     stock                                         date_range  block     MA_10  \
# 0    AAPL  2014-01-03 00:00:00+00:00 - 2014-02-14 00:00:0...      0  0.008909
# 1     DIA  2014-01-03 00:00:00+00:00 - 2014-02-14 00:00:0...      0  0.003041
# 2       F  2014-01-03 00:00:00+00:00 - 2014-02-14 00:00:0...      0  0.001854
# 3     GLD  2014-01-03 00:00:00+00:00 - 2014-02-14 00:00:0...      0  0.005713
# 4    GOOG  2014-01-03 00:00:00+00:00 - 2014-02-14 00:00:0...      0  0.001832
# ..    ...                                                ...    ...       ...
# 315   GLD  2018-08-27 00:00:00+00:00 - 2018-10-08 00:00:0...     39 -0.000823
# 316  GOOG  2018-08-27 00:00:00+00:00 - 2018-10-08 00:00:0...     39 -0.002101
# 317   IWM  2018-08-27 00:00:00+00:00 - 2018-10-08 00:00:0...     39 -0.004531
# 318   SPY  2018-08-27 00:00:00+00:00 - 2018-10-08 00:00:0...     39 -0.001106
# 319   XOM  2018-08-27 00:00:00+00:00 - 2018-10-08 00:00:0...     39 -0.000544
#
#         MA_20     MA_30   returns  future_returns
# 0   -0.000636 -0.000356 -0.010694       -0.013417
# 1   -0.000693 -0.000489 -0.014663        0.020695
# 2   -0.004265 -0.000168 -0.005054        0.023347
# 3    0.002981  0.002489  0.074683       -0.028236
# 4    0.001975  0.002583  0.077485       -0.075749
# ..        ...       ...       ...             ...
# 315 -0.000270 -0.000476 -0.014292        0.027433
# 316 -0.000677 -0.002017 -0.060518       -0.119063
# 317 -0.002553 -0.001866 -0.055973       -0.083478
# 318  0.000177  0.000186  0.005594       -0.067252
# 319  0.002634  0.002620  0.078592       -0.073543
#
# [320 rows x 8 columns]

# %%
model_train_X = training.iloc[:,3:7]
model_train_Y = training.iloc[:,7]

model_test_X = testing.iloc[:,3:7]
model_test_Y = testing.iloc[:,7]

results_df = pd.DataFrame(columns = ['Model', 'MSE'])

# %% [markdown]
# ## Modeling

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

baseline = linear_model.LinearRegression()
baseline.fit(model_train_X, model_train_Y)

results1 = mean_squared_error(model_test_Y, baseline.predict(model_test_X))
row1 = ['LinearReg', results1]
results_df.loc[len(results_df)] = row1

# %%
ridge = linear_model.Ridge(alpha=0.5)
ridge.fit(model_train_X, model_train_Y)

results2 = mean_squared_error(model_test_Y, ridge.predict(model_test_X))
row2 = ['Ridge', results2]
results_df.loc[len(results_df)] = row2

# %%
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(model_train_X, model_train_Y)

results3 = mean_squared_error(model_test_Y, lasso.predict(model_test_X))
row3 = ['Lasso', results3]
results_df.loc[len(results_df)] = row3

# %%
lasso_lars = linear_model.LassoLarsCV(cv=5)
lasso_lars.fit(model_train_X, model_train_Y)

results4 = mean_squared_error(model_test_Y, lasso_lars.predict(model_test_X))
row4 = ['Lasso_lars', results4]
results_df.loc[len(results_df)] = row4

# %%
omp = linear_model.OrthogonalMatchingPursuit()
omp.fit(model_train_X, model_train_Y)

results5 = mean_squared_error(model_test_Y, omp.predict(model_test_X))
row5 = ['OMP', results5]
results_df.loc[len(results_df)] = row5

# %%
from sklearn.ensemble import RandomForestRegressor

RF = RandomForestRegressor()
RF.fit(model_train_X, model_train_Y)

results6 = mean_squared_error(model_test_Y, RF.predict(model_test_X))
row6 = ['RF reg', results6]
results_df.loc[len(results_df)] = row6

# %%
from gplearn.genetic import SymbolicRegressor

SR = SymbolicRegressor(population_size=5000,
                           generations=20, stopping_criteria=0.01,
                           p_crossover=0.7, p_subtree_mutation=0.1,
                           p_hoist_mutation=0.05, p_point_mutation=0.1,
                           max_samples=0.9, verbose=1,
                           parsimony_coefficient=0.01, random_state=0)
SR.fit(model_train_X, model_train_Y)

results7 = mean_squared_error(model_test_Y, SR.predict(model_test_X))
row7 = ['Symbolic Reg', results7]
results_df.loc[len(results_df)] = row7
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-608016338956> in <cell line: 9>()
#       7                            max_samples=0.9, verbose=1,
#       8                            parsimony_coefficient=0.01, random_state=0)
# ----> 9 SR.fit(model_train_X, model_train_Y)
#      10
#      11 results7 = mean_squared_error(model_test_Y, SR.predict(model_test_X))
#
# /usr/local/lib/python3.10/dist-packages/gplearn/genetic.py in fit(self, X, y, sample_weight)
#     474             seeds = random_state.randint(MAX_INT, size=self.population_size)
#     475
# --> 476             population = Parallel(n_jobs=n_jobs,
#     477                                   verbose=int(self.verbose > 1))(
#     478                 delayed(_parallel_evolve)(n_programs[i],
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/gplearn/genetic.py in _parallel_evolve(n_programs, parents, X, y, sample_weight, seeds, params)
#     115                           'parent_nodes': []}
#     116
# --> 117         program = _Program(function_set=function_set,
#     118                            arities=arities,
#     119                            init_depth=init_depth,
#
# /usr/local/lib/python3.10/dist-packages/gplearn/_program.py in __init__(self, function_set, arities, init_depth, init_method, n_features, const_range, metric, p_point_replace, parsimony_coefficient, random_state, transformer, feature_names, program)
#     154         else:
#     155             # Create a naive random program
# --> 156             self.program = self.build_program(random_state)
#     157
#     158         self.raw_fitness_ = None
#
# /usr/local/lib/python3.10/dist-packages/gplearn/_program.py in build_program(self, random_state)
#     196             if (depth < max_depth) and (method == 'full' or
#     197                                         choice <= len(self.function_set)):
# --> 198                 function = random_state.randint(len(self.function_set))
#     199                 function = self.function_set[function]
#     200                 program.append(function)
#
# KeyboardInterrupt:

# %%
ridgeCV = linear_model.RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 0.4, 0.5, 0.6, 1])
ridgeCV.fit(model_train_X, model_train_Y)

results8 = mean_squared_error(model_test_Y, ridgeCV.predict(model_test_X))
row8 = ['Ridge CV', results8]
results_df.loc[len(results_df)] = row8

# %%
results_df
# Out:
#         Model       MSE
# 0   LinearReg  0.010473
# 1       Ridge  0.010485
# 2       Lasso  0.010518
# 3  Lasso_lars  0.010518
# 4         OMP  0.010487
# 5      RF reg  0.011296
# 6    Ridge CV  0.010488

# %% [markdown]
# # Using regression to calculate predicted reward and risk

# %%
testing
# Out:
#     stock                                         date_range  block     MA_10  \
# 0    AAPL  2019-01-03 00:00:00+00:00 - 2019-02-14 00:00:0...      0  0.003014
# 1     DIA  2019-01-03 00:00:00+00:00 - 2019-02-14 00:00:0...      0  0.001995
# 2       F  2019-01-03 00:00:00+00:00 - 2019-02-14 00:00:0...      0 -0.004414
# 3     GLD  2019-01-03 00:00:00+00:00 - 2019-02-14 00:00:0...      0 -0.000555
# 4    GOOG  2019-01-03 00:00:00+00:00 - 2019-02-14 00:00:0...      0  0.000474
# ..    ...                                                ...    ...       ...
# 315   GLD  2023-08-28 00:00:00+00:00 - 2023-10-09 00:00:0...     39 -0.002785
# 316  GOOG  2023-08-28 00:00:00+00:00 - 2023-10-09 00:00:0...     39  0.005398
# 317   IWM  2023-08-28 00:00:00+00:00 - 2023-10-09 00:00:0...     39 -0.001501
# 318   SPY  2023-08-28 00:00:00+00:00 - 2023-10-09 00:00:0...     39  0.000014
# 319   XOM  2023-08-28 00:00:00+00:00 - 2023-10-09 00:00:0...     39 -0.004676
#
#         MA_20     MA_30   returns  future_returns
# 0    0.005087  0.002756  0.082684        0.106267
# 1    0.002712  0.003001  0.090023        0.020297
# 2    0.001642  0.002701  0.081019        0.041867
# 3    0.000727  0.000742  0.022251       -0.016662
# 4    0.001848  0.002333  0.069989        0.045010
# ..        ...       ...       ...             ...
# 315 -0.001592 -0.000913 -0.027396        0.059255
# 316  0.000635  0.002175  0.065236       -0.011391
# 317 -0.002658 -0.001707 -0.051198        0.030172
# 318 -0.001659 -0.000470 -0.014089        0.049573
# 319 -0.001440  0.000812  0.024366       -0.050519
#
# [320 rows x 8 columns]

# %%
predictions = baseline.predict(model_test_X)

testing['pred_future_returns'] = predictions

# %%
first = testing.iloc[:8,:]
second = testing.iloc[8:16,:]

# %%
second
# Out:
#    stock                                         date_range  block     MA_10  \
# 8   AAPL  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1  0.002037
# 9    DIA  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1  0.000305
# 10     F  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1  0.004068
# 11   GLD  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1 -0.000784
# 12  GOOG  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1 -0.000946
# 13   IWM  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1 -0.000819
# 14   SPY  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1  0.000415
# 15   XOM  2019-02-15 00:00:00+00:00 - 2019-03-29 00:00:0...      1  0.000808
#
#        MA_20     MA_30   returns  future_returns  pred_future_returns
# 8   0.004107  0.003542  0.106267       -0.018677             0.007388
# 9  -0.000142  0.000677  0.020297       -0.021487             0.006189
# 10 -0.000057  0.001396  0.041867        0.153992            -0.002503
# 11  0.000053 -0.000555 -0.016662        0.005395             0.011697
# 12  0.001397  0.001500  0.045010       -0.035816             0.010735
# 13 -0.001521 -0.000059 -0.001770       -0.009582             0.006424
# 14  0.000586  0.001116  0.033489       -0.005752             0.006874
# 15  0.000498  0.001923  0.057698       -0.053670             0.003989

# %%
def transform_output(df):
  output = df[['stock', 'returns', 'pred_future_returns']].T

  output.columns = output.iloc[0]
  output = output.drop(output.index[0])

  return output

# %%
trans = transform_output(second)

# %%
trans
# Out:
# stock                    AAPL       DIA         F       GLD      GOOG  \
# returns              0.106267  0.020297  0.041867 -0.016662   0.04501
# pred_future_returns  0.007388  0.006189 -0.002503  0.011697  0.010735
#
# stock                     IWM       SPY       XOM
# returns              -0.00177  0.033489  0.057698
# pred_future_returns  0.006424  0.006874  0.003989

# %% [markdown]
# Analyzing Returns Accomplished with Linear Regression

# %%
def predicted_returns(df, weights):
  return np.dot(df.iloc[1,:].T,weights)

def predicted_std(df, weights):
  return (np.dot(np.dot(df.cov(),weights),weights))**(1/2)

# %%
def run_our_mpt(df, iterations):
  returns = []
  stds = []
  w = []
  pred_shaps = []

  for i in range(iterations): #Use the number of iterations you seem fit
      weights = weightscreator(df)
      returns.append(predicted_returns(df, weights))
      stds.append(predicted_std(df, weights))
      pred_shaps.append(predicted_returns(df, weights) / predicted_std(df, weights))
      w.append(weights)

  return pd.DataFrame({'weights' : w, 'returns' : returns,
                       'std' : stds, 'sharpe_ratio': pred_shaps})

# %%
Our_df = run_our_mpt(trans, 1000)

# %%
def get_best_ws(df):
  weights = list(df['weights'])
  sharpes = list(df['sharpe_ratio'])
  best_index = sharpes.index(max(sharpes))
  return weights[best_index]

# %%
def plot_frontier(df, title):
  returns = list(df['returns'])
  stds = list(df['std'])
  weights = list(df['weights'])


  plt.scatter(stds,returns,c="red",s=0.2,alpha=0.75) #Customise size according to number of iterations being plotter
  plt.scatter(stds[returns.index(max(returns))], max(returns),c = "green", s=3) #Customise size for this too
  plt.text(stds[returns.index(max(returns))],max(returns),"Maximum Return", fontsize=7) #Customise font size for this too
  plt.scatter(min(stds),returns[stds.index(min(stds))] ,c = "blue", s=3) #Customise size for this too
  plt.text(min(stds),returns[stds.index(min(stds))],"Minimum Variance", fontsize=7) #Customise font size for this too
  plt.title(title, fontsize = 20)
  plt.xlabel("Portfoliostd(Risk)", fontsize = 15)
  plt.ylabel("Portfolioreturn(Return)", fontsize = 15)
  plt.figure(figsize=(30,20))
  plt.show()

# %%
plot_frontier(Our_df, "Predicted Efficient Frontier")

# %% [markdown]
# ## Traditional

# %%
def portfolioreturnT(df, weights):
    return np.dot(df.mean(),weights)*252

def portfoliostdT(df, weights):
    return (np.dot(np.dot(df.cov(),weights),weights))**(1/2)*np.sqrt(252)

# %%
def run_tra_mpt(df, iterations):
  returns = []
  stds = []
  w = []
  shaps = []

  for i in range(1000): #Use the number of iterations you seem fit
      weights = weightscreator(stocks_lr)
      returns.append(portfolioreturnT(df, weights))
      stds.append(portfoliostdT(df,weights))
      w.append(weights)
      shaps.append(portfolioreturnT(df,weights) / portfoliostdT(df,weights))

  return pd.DataFrame({'weights' : w, 'returns' : returns,
                       'std' : stds, 'sharpe_ratio': shaps})

# %%
first = stocks_lr.iloc[1:31,:]
second = stocks_lr.iloc[31:61,:]

# %%
Trad = run_tra_mpt(first, 1000)
get_best_ws(Trad)
# Out:
# array([0.08528902, 0.19791047, 0.04259311, 0.3099201 , 0.22360154,
#        0.01191397, 0.09991116, 0.02886063])

# %% [markdown]
# ## Comparison

# %%
def compare_portfolios(our_weights, mpt_weights, test_df):
  our_returns = np.dot(test_df.sum(),our_weights)
  mpt_returns = np.dot(test_df.sum(),mpt_weights)

  print("Our Returns: ", our_returns)
  print("Traditional Returns: ", mpt_returns)

# %%
compare_portfolios(get_best_ws(Our_df), get_best_ws(Trad), second)
# Out:
# Our Returns:  0.0004388243154623883
# Traditional Returns:  -0.0183511534768686

# %% [markdown]
# Functions to be utalized in the future

# %%
def populate_ret_std_weight(returns, stds, weights):
  for i in range(1000): #Use the number of iterations you seem fit
      weights = weightscreator(reg_returns_data)
      returns.append(portfolioreturn(weights))
      stds.append(portfoliostd(weights))
      w.append(weights)

# %%
def plot_frontier(returns, stds, weights):
  plt.scatter(stds,returns,c="red",s=0.2,alpha=0.75) #Customise size according to number of iterations being plotter
  plt.scatter(stds[returns.index(max(returns))], max(returns),c = "green", s=3) #Customise size for this too
  plt.text(stds[returns.index(max(returns))],max(returns),"Maximum Return", fontsize=7) #Customise font size for this too
  plt.scatter(min(stds),returns[stds.index(min(stds))] ,c = "blue", s=3) #Customise size for this too
  plt.text(min(stds),returns[stds.index(min(stds))],"Minimum Variance", fontsize=7) #Customise font size for this too
  plt.title("Efficient Frontier", fontsize = 20)
  plt.xlabel("Portfoliostd(Risk)", fontsize = 15)
  plt.ylabel("Portfolioreturn(Return)", fontsize = 15)
  plt.figure(figsize=(30,20))
  plt.show()

# %%
def create_frontier_df(my_returns, my_weights, iterations):
  returns, stds = list(), list()
  weights, sharpes = list(), list()

  for i in range(iterations):
    weights = weightscreator(my_returns)

    current_returns = portfolioreturn(my_weights)
    returns.append(current_returns)

    current_std = portfoliostd(my_weights)
    stds.append(portfoliostd(my_weights))

    weights.append(my_weights)

    sharpes.append(current_returns / current_std)

  return pd.DataFrame({'weights' : weights, 'returns' : returns,
                       'std' : stds, 'sharpe_ratio': sharpes})

# %%
def get_max_return_risk(returns):
  print("Max Return: ", max(reg_returns))
  print("Standard Deviation (Risk): ", stds[returns.index(max(reg_returns))])

# %%
reg_returns = list()
reg_stds = list()
reg_weights = list()

# %%
populate_ret_std_weight(reg_returns, reg_stds, reg_weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-a61145d941d3> in <cell line: 1>()
# ----> 1 populate_ret_std_weight(reg_returns, reg_stds, reg_weights)
#
# <ipython-input-23-0d6cfc47c03f> in populate_ret_std_weight(returns, stds, weights)
#       1 def populate_ret_std_weight(returns, stds, weights):
#       2   for i in range(1000): #Use the number of iterations you seem fit
# ----> 3       weights = weightscreator(reg_returns_data)
#       4       returns.append(portfolioreturn(weights))
#       5       stds.append(portfoliostd(weights))
#
# NameError: name 'weightscreator' is not defined

# %%
plot_frontier(reg_returns, reg_stds, reg_weights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-124769051d98> in <cell line: 1>()
# ----> 1 plot_frontier(reg_returns, reg_stds, reg_weights)
#
# <ipython-input-24-8bf975165e71> in plot_frontier(returns, stds, weights)
#       1 def plot_frontier(returns, stds, weights):
#       2   plt.scatter(stds,returns,c="red",s=0.2,alpha=0.75) #Customise size according to number of iterations being plotter
# ----> 3   plt.scatter(stds[returns.index(max(returns))], max(returns),c = "green", s=3) #Customise size for this too
#       4   plt.text(stds[returns.index(max(returns))],max(returns),"Maximum Return", fontsize=7) #Customise font size for this too
#       5   plt.scatter(min(stds),returns[stds.index(min(stds))] ,c = "blue", s=3) #Customise size for this too
#
# ValueError: max() arg is an empty sequence

# %%
get_max_return_risk(reg_returns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-eff8ab231473> in <cell line: 1>()
# ----> 1 get_max_return_risk(reg_returns)
#
# <ipython-input-26-df504c97264a> in get_max_return_risk(returns)
#       1 def get_max_return_risk(returns):
# ----> 2   print("Max Return: ", max(reg_returns))
#       3   print("Standard Deviation (Risk): ", stds[returns.index(max(reg_returns))])
#
# ValueError: max() arg is an empty sequence

# %%
frontier_df = create_frontier_df(reg_returns_data, reg_weights, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0ead8c0cb6b7> in <cell line: 1>()
# ----> 1 frontier_df = create_frontier_df(reg_returns_data, reg_weights, 1000)
#
# <ipython-input-25-bd731fdd8dcc> in create_frontier_df(my_returns, my_weights, iterations)
#       4
#       5   for i in range(iterations):
# ----> 6     weights = weightscreator(my_returns)
#       7
#       8     current_returns = portfolioreturn(my_weights)
#
# NameError: name 'weightscreator' is not defined
